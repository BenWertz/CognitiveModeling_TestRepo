# %% [markdown]
# 1) FALSE (discrete probability distributions have a probability mass function, not a probability density function)
# 2) TRUE
# 3) FALSE (that's what the support is)
# 4) FALSE (counterexample: the expectation value for a random 6-sided die is 3.5. The expectation value is a sum/integral of all possible outcomes by their probability/probability density, so there's no reason the result is contained by the support.)
# 5) FALSE
# 6) O
# 7)
# 8) TRUE
